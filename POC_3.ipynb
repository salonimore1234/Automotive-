# %% [markdown]
# <a href="https://colab.research.google.com/github/salonimore1234/Automotive-/blob/main/POC_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Usecase-1 Load all three csv datasets in Pandas Data frames and display first 5 records.

# %%
ls
# Out:
# sample_data/

# %%
customers_list = ['custno','firstname','lastname','gender','age','profession','contactNo',
'emailId','city','state','isActive','createdDate','UpdatedDate']

products_list = ['productno','productName','Description','isActive','createdDate','UpdatedDate']

transactions_list = ['txnno','txndate','custno','amount','productno','spendby']

# %%
from google.colab import files
data = files.upload()
# Out:
#      <input type="file" id="files-56490632-ff5f-4a9e-9d59-2f80fae7be8d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-56490632-ff5f-4a9e-9d59-2f80fae7be8d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

# %%
dfp = pd.read_csv('products.csv', names=products_list)
dfp
# Out:
#      productno  productName Description isActive      createdDate  \
# 0            1     Product1  pgqorighfa        Y    4/3/2017 7:58
# 1            2     Product2  lmndaaweth        Y  9/21/2017 12:38
# 2            3     Product3  urifeubrhh        Y   9/8/2017 10:32
# 3            4     Product4  rlpcjxfarp        Y   5/22/2017 5:29
# 4            5     Product5  hzcpozsgfc        Y    2/2/2017 8:40
# ..         ...          ...         ...      ...              ...
# 995        996   Product996  acvxzpvhyu        Y    9/9/2017 7:49
# 996        997   Product997  eguyggimfm        Y  9/14/2017 12:13
# 997        998   Product998  hagbslxugf        Y   4/20/2017 6:25
# 998        999   Product999  iuoraxdrlf        Y    3/6/2017 5:00
# 999       1000  Product1000  ewgaacrkht        N   7/13/2017 2:52
#
#           UpdatedDate
# 0    10/18/2017 12:12
# 1    10/18/2017 12:12
# 2    10/18/2017 12:12
# 3    10/18/2017 12:12
# 4    10/18/2017 12:12
# ..                ...
# ...

# %%
dfp.head()
# Out:
#    productno productName Description isActive      createdDate  \
# 0          1    Product1  pgqorighfa        Y    4/3/2017 7:58
# 1          2    Product2  lmndaaweth        Y  9/21/2017 12:38
# 2          3    Product3  urifeubrhh        Y   9/8/2017 10:32
# 3          4    Product4  rlpcjxfarp        Y   5/22/2017 5:29
# 4          5    Product5  hzcpozsgfc        Y    2/2/2017 8:40
#
#         UpdatedDate
# 0  10/18/2017 12:12
# 1  10/18/2017 12:12
# 2  10/18/2017 12:12
# 3  10/18/2017 12:12
# 4  10/18/2017 12:12

# %%
from google.colab import files
data = files.upload()
# Out:
#      <input type="file" id="files-c95bccea-f1c7-41d5-859f-6a09d0d141b0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c95bccea-f1c7-41d5-859f-6a09d0d141b0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
dfc = pd.read_csv('customers.csv',names = customers_list)
dfc
# Out:
#      custno firstname  lastname gender  age profession  contactNo  \
# 0         1    Leslie      Bass      F   27          B      37307
# 1         2      Judy     Burks      M   53          S      84759
# 2         3    Marsha     Doyle      F   48          B      80932
# 3         4    Alexis    Battle      M   27          S      71701
# 4         5    Martha     Combs      F   49          B      83947
# ..      ...       ...       ...    ...  ...        ...        ...
# 995     964     Jared  McDowell      M   57          S      81891
# 996     965      Rita    Bender      F   46          B      57356
# 997     966     Myron     Blake      M   46          S      82675
# 998     967      Tina   Sargent      F   60          B      32097
# 999     968     Paula     Young      M   32          S      23603
#
#                           emailId        city        state isActive  \
# 0          endslost@everyma1l.org      Gibson     Dellwood        Y
# ...

# %%
dfc.head()
# Out:
#    custno firstname lastname gender  age profession  contactNo  \
# 0       1    Leslie     Bass      F   27          B      37307
# 1       2      Judy    Burks      M   53          S      84759
# 2       3    Marsha    Doyle      F   48          B      80932
# 3       4    Alexis   Battle      M   27          S      71701
# 4       5    Martha    Combs      F   49          B      83947
#
#                   emailId     city      state isActive      createdDate  \
# 0  endslost@everyma1l.org   Gibson   Dellwood        Y  9/21/2017 12:38
# 1  rfleming@hotma1l.co.uk  Suwanee     Trabue        Y   5/22/2017 5:29
# 2    arethe53@ma1lbox.net    Perry  Moxadarla        Y   9/3/2017 12:11
# 3      ofcame@ma1lbox.org   Morven     Dennis        Y   2/16/2017 4:05
# 4   camedied@everyma1l.us   Ocilla  Greenwood        Y   5/15/2017 7:34
#
#         UpdatedDate
# 0  10/18/2017 12:12
# 1  10/18/2017 12:12
# 2  10/18/2017 12:12
# 3  10/18/2017 12:12
# 4  10/18/2017 12:12

# %%
from google.colab import files
data = files.upload()
# Out:
#      <input type="file" id="files-ef53657b-9a2d-4a8b-bca8-0a1597b6b581" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ef53657b-9a2d-4a8b-bca8-0a1597b6b581">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
dft = pd.read_csv('transactions.csv',names=transactions_list)
dft
# Out:
#      txnno           txndate  custno  amount  productno spendby
# 0        1  10/18/2017 12:31     923    2559        376    Card
# 1        2  10/18/2017 12:31     219    1706        151    Card
# 2        3  10/18/2017 12:31     927    3462        707    Cash
# 3        4  10/18/2017 12:31     806     865        539    Card
# 4        5  10/18/2017 12:31     958    2494         25    Card
# ..     ...               ...     ...     ...        ...     ...
# 995    996  10/18/2017 12:31     653    2872        155    Cash
# 996    997  10/18/2017 12:31     849     815        386    Card
# 997    998  10/18/2017 12:31     939    3932        529    Card
# 998    999  10/18/2017 12:31     547    3021        774    Cash
# 999   1000  10/18/2017 12:31     204    2314        828    Card
#
# [1000 rows x 6 columns]

# %%
dft.head()
# Out:
#    txnno           txndate  custno  amount  productno spendby
# 0      1  10/18/2017 12:31     923    2559        376    Card
# 1      2  10/18/2017 12:31     219    1706        151    Card
# 2      3  10/18/2017 12:31     927    3462        707    Cash
# 3      4  10/18/2017 12:31     806     865        539    Card
# 4      5  10/18/2017 12:31     958    2494         25    Card

# %%
#usecase-2 Display only those customers from CSV_s1, who purchased more than 3 products

# %%
dfct = pd.merge(dfc,dft)
dfct
# Out:
#      custno firstname  lastname gender  age profession  contactNo  \
# 0         2      Judy     Burks      M   53          S      84759
# 1         2      Judy     Burks      M   53          S      84759
# 2         3    Marsha     Doyle      F   48          B      80932
# 3         4    Alexis    Battle      M   27          S      71701
# 4         4    Alexis    Battle      M   27          S      71701
# ..      ...       ...       ...    ...  ...        ...        ...
# 995     964     Jared  McDowell      M   57          S      81891
# 996     965      Rita    Bender      F   46          B      57356
# 997     965      Rita    Bender      F   46          B      57356
# 998     966     Myron     Blake      M   46          S      82675
# 999     967      Tina   Sargent      F   60          B      32097
#
#                           emailId        city        state isActive  \
# 0          rfleming@hotma1l.co.uk     Suwanee       Trabue        Y
# ...

# %%
gb1 = dfct.groupby('custno').count()
gb1
d1 = dfc.set_index('custno')
d1
# Out:
#        firstname  lastname gender  age profession  contactNo  \
# custno
# 1         Leslie      Bass      F   27          B      37307
# 2           Judy     Burks      M   53          S      84759
# 3         Marsha     Doyle      F   48          B      80932
# 4         Alexis    Battle      M   27          S      71701
# 5         Martha     Combs      F   49          B      83947
# ...          ...       ...    ...  ...        ...        ...
# 964        Jared  McDowell      M   57          S      81891
# 965         Rita    Bender      F   46          B      57356
# 966        Myron     Blake      M   46          S      82675
# 967         Tina   Sargent      F   60          B      32097
# 968        Paula     Young      M   32          S      23603
#
#                              emailId        city        state isActive  \
# custno
# 1             endslost@everyma1l.org      Gibson     Dellwood        Y
# ...

# %%
d1['product_pur'] = gb1['txnno']
d1
# Out:
#        firstname  lastname gender  age profession  contactNo  \
# custno
# 1         Leslie      Bass      F   27          B      37307
# 2           Judy     Burks      M   53          S      84759
# 3         Marsha     Doyle      F   48          B      80932
# 4         Alexis    Battle      M   27          S      71701
# 5         Martha     Combs      F   49          B      83947
# ...          ...       ...    ...  ...        ...        ...
# 964        Jared  McDowell      M   57          S      81891
# 965         Rita    Bender      F   46          B      57356
# 966        Myron     Blake      M   46          S      82675
# 967         Tina   Sargent      F   60          B      32097
# 968        Paula     Young      M   32          S      23603
#
#                              emailId        city        state isActive  \
# custno
# 1             endslost@everyma1l.org      Gibson     Dellwood        Y
# ...

# %%
d1[d1['product_pur'] > 3]
# Out:
#         firstname  lastname gender  age profession  contactNo  \
# custno
# 4          Alexis    Battle      M   27          S      71701
# 86         Bonnie    McCall      M   37          S      70907
# 167         Alice     Blake      F   58          B      22324
# 187          Alan   Anthony      F   50          B      40487
# 237          Dawn      West      F   26          B      75618
# 241       Derrick   Pearson      F   33          B      74138
# 321       Crystal        Le      F   64          B      37857
# 326         Heidi   Stanley      M   29          S      78822
# 331       Cynthia  Harrison      F   49          B      53439
# 356      Mitchell     Mason      M   37          S      45064
# 391         Keith    Church      F   19          B      26859
# 537          Jake      Bush      F   23          B      80535
# 558          Lois      Todd      M   58          S      39051
# 578     Christine    Murray      M   40          S      74244
# ...

# %%
##Usecase-3 Display top 5 most demanded products from CSV_s1

# %%
dfpt = pd.merge(dfp,dft)
dfpt
# Out:
#      productno productName Description isActive      createdDate  \
# 0            1    Product1  pgqorighfa        Y    4/3/2017 7:58
# 1            2    Product2  lmndaaweth        Y  9/21/2017 12:38
# 2            3    Product3  urifeubrhh        Y   9/8/2017 10:32
# 3            4    Product4  rlpcjxfarp        Y   5/22/2017 5:29
# 4            4    Product4  rlpcjxfarp        Y   5/22/2017 5:29
# ..         ...         ...         ...      ...              ...
# 995        995  Product995  fyocaaajef        Y  2/20/2017 11:05
# 996        996  Product996  acvxzpvhyu        Y    9/9/2017 7:49
# 997        997  Product997  eguyggimfm        Y  9/14/2017 12:13
# 998        998  Product998  hagbslxugf        Y   4/20/2017 6:25
# 999        998  Product998  hagbslxugf        Y   4/20/2017 6:25
#
#           UpdatedDate  txnno           txndate  custno  amount spendby
# 0    10/18/2017 12:12     20  10/18/2017 12:31     480     868    Card
# ...

# %%
gb2 = dfpt.groupby('productno').count()
gb2
# Out:
#            productName  Description  isActive  createdDate  UpdatedDate  \
# productno
# 1                    1            1         1            1            1
# 2                    1            1         1            1            1
# 3                    1            1         1            1            1
# 4                    2            2         2            2            2
# 5                    1            1         1            1            1
# ...                ...          ...       ...          ...          ...
# 994                  1            1         1            1            1
# 995                  3            3         3            3            3
# 996                  1            1         1            1            1
# 997                  1            1         1            1            1
# 998                  2            2         2            2            2
#
#            txnno  txndate  custno  amount  spendby
# productno
# ...

# %%
d1 = dfp.set_index('productno')
d1
# Out:
#            productName Description isActive      createdDate       UpdatedDate
# productno
# 1             Product1  pgqorighfa        Y    4/3/2017 7:58  10/18/2017 12:12
# 2             Product2  lmndaaweth        Y  9/21/2017 12:38  10/18/2017 12:12
# 3             Product3  urifeubrhh        Y   9/8/2017 10:32  10/18/2017 12:12
# 4             Product4  rlpcjxfarp        Y   5/22/2017 5:29  10/18/2017 12:12
# 5             Product5  hzcpozsgfc        Y    2/2/2017 8:40  10/18/2017 12:12
# ...                ...         ...      ...              ...               ...
# 996         Product996  acvxzpvhyu        Y    9/9/2017 7:49  10/18/2017 12:12
# 997         Product997  eguyggimfm        Y  9/14/2017 12:13  10/18/2017 12:12
# 998         Product998  hagbslxugf        Y   4/20/2017 6:25  10/18/2017 12:12
# 999         Product999  iuoraxdrlf        Y    3/6/2017 5:00  10/18/2017 12:12
# 1000       Product1000  ewgaacrkht        N   7/13/2017 2:52  10/18/2017 12:12
#
# ...

# %%
d1['product'] = gb2['custno']
# Out:
#           productName Description isActive      createdDate       UpdatedDate  \
# productno
# 82          Product82  ignxxzodmc        Y   9/24/2017 2:57  10/18/2017 12:12
# 768        Product768  hvfbltpjun        Y  1/27/2017 11:45  10/18/2017 12:12
# 900        Product900  ouoolyahlh        N  1/10/2017 12:35  10/18/2017 12:12
# 427        Product427  rnqzbzweys        Y  9/14/2017 10:44  10/18/2017 12:12
# 233        Product233  yrblgllvfy        Y  5/31/2017 10:50  10/18/2017 12:12
#
#            product
# productno
# 82             5.0
# 768            5.0
# 900            5.0
# 427            5.0
# 233            4.0

# %%
#Usecase-4 Display top 5 transactions amount from CSV_s1

# %%
dft.sort_values(by='amount',ascending=False,inplace=True)
dft.head()
# Out:
#      txnno           txndate  custno  amount  productno spendby
# 556    557  10/18/2017 12:31     670    4996        509    Card
# 305    306  10/18/2017 12:31     448    4992        427    Cash
# 574    575  10/18/2017 12:31     305    4981        549    Card
# 531    532  10/18/2017 12:31     230    4980        658    Card
# 232    233  10/18/2017 12:31     287    4966        685    Card

# %%
#Usecase-5 Display distinct professions from CSV_s1

# %%
dfc['profession'].unique()
# Out:
# array(['B', 'S'], dtype=object)

# %%
#Usecase-6 Display highest age in CSV_s1 customer’s dataset

# %%
dfc.sort_values(by='age',ascending=False,inplace=True)
dfc.head(1)
# Out:
#      custno firstname   lastname gender  age profession  contactNo  \
# 500     501    Morgan  Donaldson      F   64          B      52553
#
#                 emailId      city   state isActive     createdDate  \
# 500  ggordon8@yah00.biz  Elberton  Codell        Y  8/15/2017 1:08
#
#           UpdatedDate
# 500  10/18/2017 12:12

# %%
#Usecase-7 Display custno, gender, age, profession, contactno, productno, productName,txndate, spendby, amount from CSV_s1 for custno = 923

# %%
d4 = pd.merge(dfp[['productno','productName']],dft)
d4
# Out:
#      productno productName  txnno           txndate  custno  amount spendby
# 0            1    Product1     20  10/18/2017 12:31     480     868    Card
# 1            2    Product2    416  10/18/2017 12:31     217    4628    Card
# 2            3    Product3    738  10/18/2017 12:31     641    1317    Cash
# 3            4    Product4    541  10/18/2017 12:31     710    2952    Card
# 4            4    Product4    680  10/18/2017 12:31     371    4545    Card
# ..         ...         ...    ...               ...     ...     ...     ...
# 995        995  Product995    989  10/18/2017 12:31     258    4895    Card
# 996        996  Product996    824  10/18/2017 12:31     350    4804    Card
# 997        997  Product997    830  10/18/2017 12:31     414    3930    Card
# 998        998  Product998    253  10/18/2017 12:31     652    1272    Card
# 999        998  Product998    618  10/18/2017 12:31     636    3832    Cash
#
# [1000 rows x 7 columns]

# %%
d2 = pd.merge(dfc,d4)
d2
# Out:
#      custno firstname  lastname gender  age profession  contactNo  \
# 0         2      Judy     Burks      M   53          S      84759
# 1         2      Judy     Burks      M   53          S      84759
# 2         3    Marsha     Doyle      F   48          B      80932
# 3         4    Alexis    Battle      M   27          S      71701
# 4         4    Alexis    Battle      M   27          S      71701
# ..      ...       ...       ...    ...  ...        ...        ...
# 995     964     Jared  McDowell      M   57          S      81891
# 996     965      Rita    Bender      F   46          B      57356
# 997     965      Rita    Bender      F   46          B      57356
# 998     966     Myron     Blake      M   46          S      82675
# 999     967      Tina   Sargent      F   60          B      32097
#
#                           emailId        city        state isActive  \
# 0          rfleming@hotma1l.co.uk     Suwanee       Trabue        Y
# ...

# %%
cn = d2[d2['custno']==923]
cn
# Out:
#      custno firstname lastname gender  age profession  contactNo  \
# 929     923   Russell  Walters      F   46          B      25436
# 930     923   Russell  Walters      F   46          B      25436
# 931     923   Russell  Walters      F   46          B      25436
#
#                  emailId      city  state isActive     createdDate  \
# 929  esears55@ma1lbox.us  Cuthbert  Odell        Y  7/30/2017 1:30
# 930  esears55@ma1lbox.us  Cuthbert  Odell        Y  7/30/2017 1:30
# 931  esears55@ma1lbox.us  Cuthbert  Odell        Y  7/30/2017 1:30
#
#           UpdatedDate  productno productName  txnno           txndate  amount  \
# 929  10/18/2017 12:12        113  Product113    335  10/18/2017 12:31    2303
# 930  10/18/2017 12:12        376  Product376      1  10/18/2017 12:31    2559
# 931  10/18/2017 12:12        644  Product644    933  10/18/2017 12:31    4553
#
#     spendby
# 929    Card
# 930    Card
# 931    Cash

# %%
#Usecase-8 Load all three PSV (pipe separated values) dataset in Pandas Data frames and display first 5 records.

# %% [markdown]
# # New section

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
from google.colab import files
data = files.upload()
# Out:
#      <input type="file" id="files-fde1d861-b702-41b1-9a02-f056dd1342ea" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fde1d861-b702-41b1-9a02-f056dd1342ea">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
p1 = pd.read_csv('customers.txt',delimiter = '|',names=customers_list)
p1
# Out:
#      custno firstname   lastname gender  age profession  contactNo  \
# 0         1    Leslie       Bass      F   27          B      37307
# 1         2      Judy      Burks      M   53          S      84759
# 2         3    Marsha      Doyle      F   48          B      80932
# 3         4    Alexis     Battle      M   27          S      71701
# 4         5    Martha      Combs      F   49          B      83947
# ..      ...       ...        ...    ...  ...        ...        ...
# 995     996   Roxanne  Velazquez      M   37          S      57463
# 996     997   Kristen       Wall      F   20          B      62662
# 997     998     Terry  Blackwell      M   28          S      49457
# 998     999     Betty       Leon      F   23          B      69268
# 999    1000    Connie    Andrews      M   47          S      78445
#
#                          emailId                 city      state isActive  \
# 0         endslost@everyma1l.org               Gibson   Dellwood        Y
# ...

# %%
p1.head()
# Out:
#    custno firstname lastname gender  age profession  contactNo  \
# 0       1    Leslie     Bass      F   27          B      37307
# 1       2      Judy    Burks      M   53          S      84759
# 2       3    Marsha    Doyle      F   48          B      80932
# 3       4    Alexis   Battle      M   27          S      71701
# 4       5    Martha    Combs      F   49          B      83947
#
#                   emailId     city      state isActive          createdDate  \
# 0  endslost@everyma1l.org   Gibson   Dellwood        Y  2017-09-21 12:38:22
# 1  rfleming@hotma1l.co.uk  Suwanee     Trabue        Y  2017-05-22 05:29:22
# 2    arethe53@ma1lbox.net    Perry  Moxadarla        Y  2017-09-03 12:11:29
# 3      ofcame@ma1lbox.org   Morven     Dennis        Y  2017-02-16 04:05:35
# 4   camedied@everyma1l.us   Ocilla  Greenwood        Y  2017-05-15 07:34:35
#
#            UpdatedDate
# 0  2017-10-18 12:12:28
# 1  2017-10-18 12:12:28
# 2  2017-10-18 12:12:28
# 3  2017-10-18 12:12:28
# ...

# %%
from google.colab import files
data = files.upload()
# Out:
#      <input type="file" id="files-5cbd8f91-5c74-4823-87b9-701047cb8781" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5cbd8f91-5c74-4823-87b9-701047cb8781">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
p2 = pd.read_csv('products.txt',delimiter = '|',names=products_list)
p2.head()
# Out:
#    productno productName Description isActive          createdDate  \
# 0          1    Product1  pgqorighfa        Y  2017-04-03 07:58:55
# 1          2    Product2  lmndaaweth        Y  2017-09-21 12:38:31
# 2          3    Product3  urifeubrhh        Y  2017-09-08 10:32:12
# 3          4    Product4  rlpcjxfarp        Y  2017-05-22 05:29:27
# 4          5    Product5  hzcpozsgfc        Y  2017-02-02 08:40:29
#
#            UpdatedDate
# 0  2017-10-18 12:12:38
# 1  2017-10-18 12:12:38
# 2  2017-10-18 12:12:38
# 3  2017-10-18 12:12:38
# 4  2017-10-18 12:12:38

# %%
from google.colab import files
data = files.upload()
# Out:
#      <input type="file" id="files-9ba101cb-930a-4ba1-b52f-ba836851af95" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9ba101cb-930a-4ba1-b52f-ba836851af95">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
p3 = pd.read_csv('transactions.txt',delimiter = '|',names=transactions_list)
p3.head()
# Out:
#    txnno              txndate  custno  amount  productno spendby
# 0      1  2017-10-18 12:31:45     923    2559        376    Card
# 1      2  2017-10-18 12:31:45     219    1706        151    Card
# 2      3  2017-10-18 12:31:45     927    3462        707    Cash
# 3      4  2017-10-18 12:31:45     806     865        539    Card
# 4      5  2017-10-18 12:31:45     958    2494         25    Card

# %%
#Usecase-9 Load all three JSON datasets in Pandas Data frames and display first 5 records.

# %%
import pandas as pd

# %%
from google.colab import files
data = files.upload()
# Out:
#      <input type="file" id="files-7b220c32-0d49-4ed8-854d-92d76175244e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7b220c32-0d49-4ed8-854d-92d76175244e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
dfj1 = pd.read_json('transactions (1).json',lines = True)
dfj1
# Out:
#     txnno     txndate  custno  amount  productno  spendby
# 0       1  2018-07-31      71     181         19        2
# 1       2  2017-04-02      44     401         48        2
# 2       3  2018-01-31      45    1808         44        2
# 3       4  2018-04-02      62      65         22        2
# 4       5  2017-08-17      88    1149         74        2
# ..    ...         ...     ...     ...        ...      ...
# 95     96  2017-02-14      81     124         29        1
# 96     97  2017-11-16       2     672         78        1
# 97     98  2018-08-14      43     538         61        1
# 98     99  2017-05-06      74    1856         95        2
# 99    100  2017-08-28      85     273         99        2
#
# [100 rows x 6 columns]

# %%
dfj1.head()
# Out:
#    txnno     txndate  custno  amount  productno  spendby
# 0      1  2018-07-31      71     181         19        2
# 1      2  2017-04-02      44     401         48        2
# 2      3  2018-01-31      45    1808         44        2
# 3      4  2018-04-02      62      65         22        2
# 4      5  2017-08-17      88    1149         74        2

# %%
from google.colab import files
data = files.upload()
# Out:
#      <input type="file" id="files-5829a395-4201-4315-8a6e-38ba79cfb056" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5829a395-4201-4315-8a6e-38ba79cfb056">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
dfj2 = pd.read_json('products.json',lines = True)
dfj2
# Out:
#     productno     productName Description  isActive createdDate UpdatedDate
# 0         100        Vauxhall        four         2  2016-11-21  2017-11-09
# 1         101          Toyota         six         2  2017-10-03  2017-11-13
# 2         102  General Motors         two         1  2017-09-18  2017-11-03
# 3         103         Renault       eight         2  2017-10-05  2017-11-13
# 4         104        Kenworth       three         1  2017-05-03  2017-11-04
# ..        ...             ...         ...       ...         ...         ...
# 95        195             BMW        nine         2  2017-05-06  2017-11-18
# 96        196            Fiat       seven         2  2016-11-13  2017-11-17
# 97        197         Renault        five         1  2017-09-23  2017-11-16
# 98        198      Kia Motors       seven         2  2017-05-27  2017-11-02
# 99        199      RAM Trucks       eight         2  2017-04-05  2017-11-20
#
# [100 rows x 6 columns]

# %%
dfj2.head()
# Out:
#    productno     productName Description  isActive createdDate UpdatedDate
# 0        100        Vauxhall        four         2  2016-11-21  2017-11-09
# 1        101          Toyota         six         2  2017-10-03  2017-11-13
# 2        102  General Motors         two         1  2017-09-18  2017-11-03
# 3        103         Renault       eight         2  2017-10-05  2017-11-13
# 4        104        Kenworth       three         1  2017-05-03  2017-11-04

# %%
from google.colab import files
data = files.upload()
# Out:
#      <input type="file" id="files-2847c010-2385-463f-a27f-779d2acb43a2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2847c010-2385-463f-a27f-779d2acb43a2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
dfj3 = pd.read_json('customers.json',lines = True)
dfj3
# Out:
#     custno  firstname    lastname  gender  age          profession  \
# 0        1        Dai       Noble       2   53     Human Resources
# 1        2        Kay        Wise       2   26    Public Relations
# 2        3       Amir        Pace       1   43  Customer Relations
# 3        4  Sebastian       Lopez       2   32  Customer Relations
# 4        5      Brian      Maddox       1   40   Quality Assurance
# ..     ...        ...         ...     ...  ...                 ...
# 95      96     Tanner     Webster       1   29          Accounting
# 96      97    Tatiana       Gates       2   54         Advertising
# 97      98     Baxter  Valenzuela       1   43    Asset Management
# 98      99   Chadwick     Mcclure       2   42             Payroll
# 99     100       Tate       Booth       2   53         Advertising
#
#         contactNo                               emailId                 city  \
# 0   1644101928099          eu.lacus.Quisque@loremac.com               Berlin
# ...

# %%
dfj3.head()
# Out:
#    custno  firstname lastname  gender  age          profession      contactNo  \
# 0       1        Dai    Noble       2   53     Human Resources  1644101928099
# 1       2        Kay     Wise       2   26    Public Relations  1674031917099
# 2       3       Amir     Pace       1   43  Customer Relations  1636050509999
# 3       4  Sebastian    Lopez       2   32  Customer Relations  1666010108899
# 4       5      Brian   Maddox       1   40   Quality Assurance  1646080399299
#
#                         emailId             city       state  isActive  \
# 0  eu.lacus.Quisque@loremac.com           Berlin      Berlin         1
# 1          ridiculus@Sednunc.ca        Oldenzaal  Overijssel         2
# 2    quam.Pellentesque@erat.edu          Cobourg     Ontario         2
# 3           magna@venenatis.net       Te Awamutu          NI         1
# 4         ac.facilisis@Duis.com  Greater Sudbury     Ontario         2
#
#   createdDate UpdatedDate
# 0  2017-03-01  2018-08-25
# ...

# %%
#Usecase-10 Load all three XML datasets in Pandas Data frames and display first 5 records.

# %%
import pandas as pd

# %%
from google.colab import files
data = files.upload()
# Out:
#      <input type="file" id="files-9dbf124d-c3b9-433d-804a-2080d775c2f1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9dbf124d-c3b9-433d-804a-2080d775c2f1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df8 = pd.read_xml('transactions.xml')
df8
# Out:
#     txnno     txndate  custno  amount  productno  spendby
# 0       1  2018-09-16       6     576         73        1
# 1       2  2018-02-11      96    1038         40        2
# 2       3  2017-06-13      17     673          2        1
# 3       4  2017-07-25      89    1284        100        2
# 4       5  2017-06-15       9    1685         56        2
# ..    ...         ...     ...     ...        ...      ...
# 95     96  2018-11-10      59    1388         26        2
# 96     97  2017-09-13      57    1261         36        2
# 97     98  2017-10-29       7      93         60        1
# 98     99  2017-09-30       4     643         38        1
# 99    100  2017-10-12      77    1902         54        2
#
# [100 rows x 6 columns]

# %%
df8.head()
# Out:
#    txnno     txndate  custno  amount  productno  spendby
# 0      1  2018-09-16       6     576         73        1
# 1      2  2018-02-11      96    1038         40        2
# 2      3  2017-06-13      17     673          2        1
# 3      4  2017-07-25      89    1284        100        2
# 4      5  2017-06-15       9    1685         56        2

# %%
from google.colab import files
data = files.upload()
# Out:
#      <input type="file" id="files-352d185f-8a17-4af1-adba-e71407d0a430" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-352d185f-8a17-4af1-adba-e71407d0a430">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df9 = pd.read_xml('products.xml')
df9
# Out:
#     productno     productName Description  isActive createdDate UpdatedDate
# 0         100  Hyundai Motors       eight         2  2017-10-01  2017-11-04
# 1         101           Honda       eight         1  2017-04-10  2017-11-11
# 2         102             GMC       three         2  2017-02-09  2017-11-17
# 3         103           Lexus       eight         2  2017-06-01  2017-11-04
# 4         104           Smart        five         2  2017-08-10  2017-11-16
# ..        ...             ...         ...       ...         ...         ...
# 95        195           Honda        four         2  2016-11-09  2017-11-19
# 96        196     Tata Motors       three         2  2016-11-17  2017-11-03
# 97        197        Kenworth        nine         1  2017-09-21  2017-11-09
# 98        198           Skoda        nine         2  2017-04-14  2017-11-14
# 99        199             BMW         six         2  2017-06-23  2017-11-15
#
# [100 rows x 6 columns]

# %%
df9.head()
# Out:
#    productno     productName Description  isActive createdDate UpdatedDate
# 0        100  Hyundai Motors       eight         2  2017-10-01  2017-11-04
# 1        101           Honda       eight         1  2017-04-10  2017-11-11
# 2        102             GMC       three         2  2017-02-09  2017-11-17
# 3        103           Lexus       eight         2  2017-06-01  2017-11-04
# 4        104           Smart        five         2  2017-08-10  2017-11-16

# %%
from google.colab import files
data = files.upload()
# Out:
#      <input type="file" id="files-6892b083-c462-48c0-a473-493f9d397503" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6892b083-c462-48c0-a473-493f9d397503">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df10 = pd.read_xml('customers.xml')
df10
# Out:
#     custno firstname  lastname  gender  age          profession  \
# 0        1    Teegan   Hubbard       2   33     Human Resources
# 1        2    Deacon    Briggs       2   54  Customer Relations
# 2        3   Mallory   Shelton       1   57  Customer Relations
# 3        4     Quinn  Clements       2   43     Media Relations
# 4        5    Arthur     Hurst       2   41        Tech Support
# ..     ...       ...       ...     ...  ...                 ...
# 95      96   Harriet    Moreno       1   33    Legal Department
# 96      97      Nell    Sparks       1   63    Asset Management
# 97      98    Ashely      Lynn       1   30    Customer Service
# 98      99     Emily  Williams       2   30            Finances
# 99     100    Tashya    Dudley       1   31  Customer Relations
#
#         contactNo                                       emailId  \
# 0   1681121691699                     nibh.Quisque@placerat.com
# 1   1631082682999                    facilisis.eget@Nullaeu.com
# ...

# %%
df10.head()
# Out:
#    custno firstname  lastname  gender  age          profession      contactNo  \
# 0       1    Teegan   Hubbard       2   33     Human Resources  1681121691699
# 1       2    Deacon    Briggs       2   54  Customer Relations  1631082682999
# 2       3   Mallory   Shelton       1   57  Customer Relations  1627011572699
# 3       4     Quinn  Clements       2   43     Media Relations  1618122268999
# 4       5    Arthur     Hurst       2   41        Tech Support  1681021022799
#
#                           emailId             city         state  isActive  \
# 0       nibh.Quisque@placerat.com       Galashiels  Selkirkshire         1
# 1      facilisis.eget@Nullaeu.com  Lens-Saint-Remy            LU         1
# 2    Curabitur.ut@Nullatempor.edu      North Shore            NI         1
# 3  metus.Vivamus.euismod@urna.edu          Heredia             H         1
# 4             in@commodoipsum.org        San Diego       Cartago         2
#
#   createdDate UpdatedDate
# ...
